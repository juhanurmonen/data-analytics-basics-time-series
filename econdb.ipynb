# %% [markdown]
# # Econdb &mdash; The Database of Economic Indicators

# %% [markdown]
# Econdb https://www.econdb.com/ contains a lot of economics related time series. Searches can be done using tickers or Python commands provided by Econdb.

# %% [markdown]
# You can install a new library in the following way.
# - Open Anaconda Navigator and choose **Environments**.
# - If **pandas-datareader** is not found in the list of **Installed**, select the list **Not installed**.
# - If **pandas-datareader** is not in this list either, update the list (**Update index**).
# - Choose **pandas-datareader** and in the bottom of the window select **Apply**.

# %%
### Import the libraries

import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
# %matplotlib inline

# %% [markdown]
# ### Searching using tickers

# %%
### Real values of Finland's gross domestic product.

df1 = web.DataReader('ticker=RGDPFI', 'econdb')

### Real values of Sweden's gross domestic product.

df2 = web.DataReader('ticker=RGDPSE', 'econdb')

### Combine the data and tarnsform values into percentages of change

df3 = pd.concat([df1.pct_change(), df2.pct_change()], axis = 1)
df3.columns = ['Finland', 'Sweden']
df3
# Out:
#               Finland    Sweden
# TIME_PERIOD
# 2018-07-01        NaN       NaN
# 2018-10-01   0.000388  0.013326
# 2019-01-01   0.006387  0.005250
# 2019-04-01   0.008783  0.006086
# 2019-07-01   0.000348  0.001245
# 2019-10-01  -0.001876  0.004691
# 2020-01-01  -0.002820 -0.002271
# 2020-04-01  -0.062557 -0.080685
# 2020-07-01   0.049527  0.073080
# 2020-10-01   0.008054  0.001518
# 2021-01-01  -0.002393  0.015031
# 2021-04-01   0.014660  0.008431
# 2021-07-01   0.010327  0.017867
# 2021-10-01   0.010273  0.021250
# 2022-01-01  -0.000801 -0.001857
# 2022-04-01   0.009751  0.002072
# 2022-07-01  -0.002279  0.003432
# 2022-10-01  -0.003858 -0.004939

# %%
### Draw the calculation results

df3.plot()
plt.axhline(y=0, color = 'gray', linewidth = 1, linestyle = '--')

# %%
### Calculate the correlation between the two

df3.corr()
# Out:
#           Finland    Sweden
# Finland  1.000000  0.958592
# Sweden   0.958592  1.000000

# %% [markdown]
# ### Searching using the code copied from Econdb

# %%
### The following code has been copied from Econdb

df = web.DataReader('dataset=NAMQ_10_GDP&v=Geopolitical entity (reporting)&h=TIME&from=2017-08-01&GEO=\
    [AL,AT,BE,BA,BG,HR,CY,CZ,DK,EE,EA19,FI,FR,DE,EL,HU,IS,IE,IT,XK,LV,LT,LU,MT,ME,NL,MK,NO,PL,PT,RO,RS,SK,SI,ES,SE,CH,TR,UK]\
    &NA_ITEM=[B1GQ]&S_ADJ=[SCA]&UNIT=[CLV10_MNAC]', 'econdb')

df
# Out:
# Frequency                                                                                 Quarterly  \
# Unit of measure                     Chain linked volumes (2010), million units of national currency
# Seasonal adjustment                                           Seasonally and calendar adjusted data
# National accounts indicator (ESA10)                         Gross domestic product at market prices
# Geopolitical entity (reporting)                                                             Austria
# TIME_PERIOD
# 2017-10-01                                                                       82204
# 2018-01-01                                                                       82842
# 2018-04-01                                                                       83008
# 2018-07-01                                                                       83418
# 2018-10-01                                                                       84387
# 2019-01-01                                                                       84830
# 2019-04-01                                                                       84436
# 2019-07-01                                                                       84920
# 2019-10-01                                                                       84473
# 2020-01-01                                                                       82395
# 2020-04-01                                                                       72976
# 2020-07-01                                                                       81261
# 2020-10-01                                                                       79848
# 2021-01-01                                                                       78838
# 2021-04-01                                                                       82092
# 2021-07-01                                                                       85577
# 2021-10-01                                                                       84930
# 2022-01-01                                                                       85621
# 2022-04-01                                                                       87396
# 2022-07-01                                                                       87478
# 2022-10-01                                                                       87447
#
# Frequency                                                                     \
# Unit of measure
# Seasonal adjustment
# National accounts indicator (ESA10)
# Geopolitical entity (reporting)     Belgium Bulgaria Croatia Cyprus  Czechia
# TIME_PERIOD
# 2017-10-01                           100287    21331   11859   5135  1191388
# 2018-01-01                           100660    21429   11867   5259  1197842
# 2018-04-01                           101116    21616   12100   5278  1205050
# 2018-07-01                           101511    21837   12154   5342  1213636
# 2018-10-01                           102503    22030   12213   5436  1222602
# 2019-01-01                           102784    22305   12462   5536  1233752
# 2019-04-01                           103352    22556   12524   5596  1242059
# 2019-07-01                           104105    22598   12515   5657  1250401
# 2019-10-01                           104725    22862   12515   5704  1256445
# 2020-01-01                           101698    21996   12375   5658  1215704
# 2020-04-01                            90106    20932   10547   5002  1108129
# 2020-07-01                           100699    21684   11156   5326  1185180
# 2020-10-01                           100208    22079   11815   5525  1198697
# 2021-01-01                           101636    22686   12660   5626  1192762
# 2021-04-01                           103433    22980   12725   5646  1209339
# 2021-07-01                           105861    23417   13027   5777  1229871
# 2021-10-01                           106470    23768   13294   5889  1240324
# 2022-01-01                           107126    23853   13616   6003  1248326
# 2022-04-01                           107698    24029   13797   5990  1251668
# 2022-07-01                           108036    24170   13730   6086  1248281
# 2022-10-01                           108096    24317   13854   6151  1243888
#
# Frequency                                                            ...  \
# Unit of measure                                                      ...
# Seasonal adjustment                                                  ...
# National accounts indicator (ESA10)                                  ...
# Geopolitical entity (reporting)     Denmark Estonia Finland  France  ...
# TIME_PERIOD                                                          ...
# 2017-10-01                           515784    4804   50587  549308  ...
# 2018-01-01                           518425    4838   50727  549666  ...
# 2018-04-01                           521031    4880   50667  552129  ...
# 2018-07-01                           524168    4922   50620  554222  ...
# 2018-10-01                           526786    4976   50639  557479  ...
# 2019-01-01                           525636    5052   50963  561169  ...
# 2019-04-01                           530920    5061   51410  565084  ...
# 2019-07-01                           533348    5076   51428  565200  ...
# 2019-10-01                           531726    5134   51332  563750  ...
# 2020-01-01                           529254    5171   51187  532280  ...
# 2020-04-01                           497370    4823   47985  460028  ...
# 2020-07-01                           525552    5048   50361  544782  ...
# 2020-10-01                           527136    5185   50767  539802  ...
# 2021-01-01                           530763    5333   50646  540110  ...
# 2021-04-01                           542274    5475   51388  545868  ...
# 2021-07-01                           545765    5507   51919  564122  ...
# 2021-10-01                           561476    5530   52452  567391  ...
# 2022-01-01                           559364    5508   52410  566103  ...
# 2022-04-01                           566528    5444   52921  568945  ...
# 2022-07-01                           567233    5374   52800  569904  ...
# 2022-10-01                           570417    5286   52597  570332  ...
#
# Frequency                                                                      \
# Unit of measure
# Seasonal adjustment
# National accounts indicator (ESA10)
# Geopolitical entity (reporting)     Greece Portugal Romania   Serbia Slovakia
# TIME_PERIOD
# 2017-10-01                           46073    45955  175236   904724    20711
# 2018-01-01                           46659    46290  178180   926262    20900
# 2018-04-01                           46810    46650  180978   936160    21147
# 2018-07-01                           46752    46896  183407   938306    21359
# 2018-10-01                           47069    47181  185103   938774    21470
# 2019-01-01                           47441    47598  186855   950671    21652
# 2019-04-01                           47941    47870  188483   964661    21716
# 2019-07-01                           47743    48086  189513   985131    21768
# 2019-10-01                           47601    48481  190599  1001054    21877
# 2020-01-01                           46705    46369  191886   998637    21271
# 2020-04-01                           40466    39358  173506   905525    19695
# 2020-07-01                           42607    45100  179857   972043    21509
# 2020-10-01                           44338    45267  186155   990035    21603
# 2021-01-01                           45794    44108  189934  1015390    21291
# 2021-04-01                           46388    46061  193406  1029131    21699
# 2021-07-01                           47890    47352  195023  1049725    21772
# 2021-10-01                           48142    48264  196172  1064296    21849
# 2022-01-01                           49217    49354  198709  1054921    21909
# 2022-04-01                           49763    49450  201114  1068332    21982
# 2022-07-01                           49984    49614  203545  1060627    22053
# 2022-10-01                           50667    49788  205669  1068426    22113
#
# Frequency                                                                  \
# Unit of measure
# Seasonal adjustment
# National accounts indicator (ESA10)
# Geopolitical entity (reporting)     Slovenia   Spain   Sweden Switzerland
# TIME_PERIOD
# 2017-10-01                             10306  287081  1051488      178187
# 2018-01-01                             10307  288307  1055395      180198
# 2018-04-01                             10448  289996  1066566      181902
# 2018-07-01                             10590  291506  1057753      181307
# 2018-10-01                             10717  293427  1071849      181808
# 2019-01-01                             10781  295214  1077476      182052
# 2019-04-01                             10744  296236  1084033      182838
# 2019-07-01                             10920  297110  1085382      183822
# 2019-10-01                             11050  297755  1090474      184923
# 2020-01-01                             10525  281416  1087997      182139
# 2020-04-01                              9500  231250  1000212      169288
# 2020-07-01                             10733  269726  1073308      181596
# 2020-10-01                             10598  269567  1074936      182223
# 2021-01-01                             10780  268950  1091094      181969
# 2021-04-01                             10994  272587  1100294      185586
# 2021-07-01                             11311  281060  1119952      188762
# 2021-10-01                             11694  287426  1143751      189121
# 2022-01-01                             11816  287400  1141627      189756
# 2022-04-01                             11910  293832  1143993      190308
# 2022-07-01                             11758  294375  1147919      190616
# 2022-10-01                             11850  294930  1142250      190666
#
# Frequency
# Unit of measure
# Seasonal adjustment
# National accounts indicator (ESA10)
# Geopolitical entity (reporting)        Turkey
# TIME_PERIOD
# 2017-10-01                           467628.0
# 2018-01-01                           474496.0
# 2018-04-01                           477616.0
# 2018-07-01                           469841.0
# 2018-10-01                           454881.0
# 2019-01-01                           463422.0
# 2019-04-01                           475322.0
# 2019-07-01                           473645.0
# 2019-10-01                           479707.0
# 2020-01-01                           483781.0
# 2020-04-01                           433605.0
# 2020-07-01                           501461.0
# 2020-10-01                           506900.0
# 2021-01-01                           520164.0
# 2021-04-01                           530541.0
# 2021-07-01                           544942.0
# 2021-10-01                           553529.0
# 2022-01-01                           556791.0
# 2022-04-01                           567227.0
# 2022-07-01                           566520.0
# 2022-10-01                                NaN
#
# [21 rows x 33 columns]

# %% [markdown]
# Source and origin of inspiration:<br />
# Aki Taanila: Data-analytiikka Pythonilla: <a href="https://tilastoapu.wordpress.com/python/">https://tilastoapu.wordpress.com/python/</a>

# %%
import datetime
print(f'Last modified {datetime.datetime.now():%Y-%m-%d %H:%M} by Juha Nurmonen')
# Out:
# Last modified 2023-04-20 22:00 by Juha Nurmonen
